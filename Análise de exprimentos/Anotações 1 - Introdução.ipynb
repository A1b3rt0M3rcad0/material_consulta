# %% [markdown]
# ## Introdução

# %% [markdown]
# Ao longo dos estudos iremos acompanhar a personagem, bell ela gostaria de entender
# como a quantidade de farinha e chocolate influência na quantidade de cupcakes produzidos.
# Para isso vamos passar desde o planejamento para coleta de dados, coletando os dados
# e também analisando os resultados obtidos.

# %% [markdown]
# ## O caso de estudos

# %% [markdown]
# Antes de ser planejado qualquer experimento, primeiro temos que entender qual sistema iremos estudar.
# No caso em estudo Bell quer entender melhor a sua receita, para que ela possa sair de uma produção
# em pequena escala para uma em grande escala. Além de evitar gostos desnecessários com ingredientes,
# também melhorando a qualidade de seus cupcakes, e aumentando a fornada produzida, sempre buscando
# o aumento dos seus lucros.
# Bel quer entender mais sobre 2 ingredientes utilizados em sua receita, o chocolate e a farinha,
# como eles afetam a sua receita além de qual deles tem mais importância da sua produção. E qual deles
# afeta da produção de mais cupcakes.
# Para atinger os objetivos sera elaborado um experimento em que temos na receita a variação de apenas
# 2 ingredientes a farinha e o chocolate e depois será contabilizado a quantidade de cupcakes produzidos.
# Antes de começar a desenvolver esses experimento vamos entender melhor, como eles podem ser planejados.

# %% [markdown]
# ## Planejar é preciso

# %% [markdown]
# Vimos então quer bel deseja variar 2 ingredientes para ver como afeta na sua produção de cupcakes.
# A ideia então é variar a farinha e o chocolate. Então para que se possa realizar o experimentos
# devem ser coletados dados de varias fornadas variam esse 2 ingredientes e anotado quantos cupcakes são
# produzidos no final a seguir temos a receita da bel para esses cupcakes:
#
# ![image.png](attachment:image.png)
#
# Para que os experimentos sejam realizados de forma correta, devemos analisar apenas a variação do chocolate e a farinha
# mantendo todos os outros ingredientes constantes. Além de seguir a risca a receita sem alterar qualquer ingrediente.
#
# Para que se possa realizar os experimentos sempre se deve ter um objetivo bem estabelecido, ter um objetivo bem
# estabelecido evita erros ao realizar os experimentos. Além de entender quais serão as variáveis manipuladas, no nosso caso
# são a farinha e o chocolate. E a resposta sendo aquilo que desejamos, obtendo ela por meio de métodos estátisticos, no caso
# nosso seria o número de cupcakes produzidos.

# %% [markdown]
# ## Coletando dados do infinito ao finito

# %% [markdown]
# Vamos dar continuidade ao planejamento do experimento da bell, para isso precisamos definir uma faixa
# de variação do chocolate e da farinha, para que não tenhamos o problema de poder infinitos experimentos.
# Ou seja, precisamos definir essa faixa para que o chocolocate e a farinha não tenham infinitas variações,
# pois existem muitos problemas nisso, além de ser bem impossivel para bell preparar grandes quantidade
# de cupcakes em sua cozinha.
#
# ![image.png](attachment:image.png)
#
# Bom como bem sabemos não podemos ter quantidade negativas de produtos, então o menos infinito na descartado.
# nos deixando apenas com o lado do mais infinito.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# Ainda que tiramos o lado do menos infinito, continuamos com o problema das infinitas variações.
# Para resolver esse problema vamos definir limites superiores e inferiores para o chocolate e farinha.
# sabemos que para produzir o cupcake não podemos ter quantidade 0 para qualquer um dos produtos, então
# seria maior que zero, mas quanto? para isso consultamos alguns livros de receita de cupcakes e tiramos algumas
# conclusões dos limites inferiores e superiores. Uma das informações extras seria que a ball gostaria de fazer fornadas
# de 50 cupcakes. Após a "revisão bibliográfica" tiramos a seguinte conclusão
#
# ![image-4.png](attachment:image-4.png)
#
# sendo acima a tabela dos limites inferiores e superiores.
# com isso vamos orfanizar melhor, colocando os dados em uma reta e mostando um plano cartesiano
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# com o plano cartesiano montado vamos definir os limitesda area.
#
# ![image-7.png](attachment:image-7.png)
#
# difinindo os limites de area temos um retângulo.
# Apenas da area ser limitada ainda caímos no problema de infinitos experimentos, nesse espaço temos infinitos experimentos para se coletar. vamos utilizar então uma lógica bem proxima da inferencia estatistica. retirando amostras finitas para inferirmos sobre as caracteristiacs da população. Essa tecnica é utilizada quando temos informações de populações com grande quantidade de dados. Agindo dessa forma vamos montar o espaço experimental sendo montados por finitos pontos:
#
# ![image-8.png](attachment:image-8.png)
#
# dessa forma saimos do problema dos infinitos.
# Lembrando que os pontos escolhidos devem ser representativos da área.

# %% [markdown]
# ## Planejamentos fatoriais

# %% [markdown]
# Os pontos experimentaris que serão escolhidos devem conter informações representativas sobre o espaço experimental,
# Forma ruins de coletar esses pontos, seria mantar uma das variaveis constantes e alterar outra, pois não iremos conseguir
# entender como uma das variaveis altera o valor final, no caso a produção dos cupcakes. Da mesma forma utilizando
# pontos aleatorios, nesse caso seria preciso gerar muitos pontos para garantir que foi percorrido toda a totalidade da area
# experimental e seria muito custoso, quando o custo do experimento é muito custoso a melhor forma seria utilizar o planejamento
# fatorial, que é basicamento os vertices da area exprimental, para sabermos o numeros de vertices temos que pegar
# o numero de limites, no caso limite superior e inferior que são 2 e elevarmos ao numero de variaveis que tambem são 2
# chocolate e farinha e assim temos os números de ensaios utilizados 2^2 = 4 ou 2^v.

# %% [markdown]
# ### Para Saber +:
# Pontos experimentais normalizados
#
# Como dito, tradicionalmente o planejamento fatorial utiliza as variáveis normalizadas entre -1 e +1. Essa normalização evita termos que lidar com variáveis que possuem magnitudes muito diferentes. Além disso, o uso de valores normalizados permite a inserção de variáveis não numéricas no experimento. Por exemplo, a Bel poderia avaliar o efeito de duas marcas de fermento na quantidade de cupcakes produzidos. Vamos chamar essas duas marcas de A e B. Se não tivéssemos lidando com variáveis normalizadas, não seria direta a inclusão do efeito da marca do fermento na resposta analisada no experimento. Contudo, trabalhando com variáveis normalizadas, essa inserção torna-se natural. Para isso, bastaria dizer que, por exemplo, a marca A será o nível -1 e a marca B o +1. Pronto! Seremos capazes de analisar essa variável não numérica em conjunto com as demais, uma vez que todas elas estão definidas entre os limites -1 e +1.
